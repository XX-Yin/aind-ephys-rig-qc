# %%
import numpy as np

# File paths.
continuous_dat_path = r'X:\0\0_2025-02-12_11-18-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeA\continuous.dat'
sample_numbers_npy_path = r'X:\0\0_2025-02-12_11-18-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeA\sample_numbers.npy'
timestamps_npy_path = r'X:\0\0_2025-02-12_11-18-01\Record Node 103\experiment1\recording1\continuous\Neuropix-PXI-100.ProbeA\timestamps.npy'

# Read the files:
# For continuous.dat, we assume the data are stored as 32-bit floats.
continuous_dat = np.fromfile(continuous_dat_path, dtype=np.float32)
# If the data are multi-dimensional (for example, channels x samples), you might need to reshape.
# Example: continuous_dat = continuous_dat.reshape((n_channels, n_samples))

sample_numbers_npy = np.load(sample_numbers_npy_path)
timestamps_npy = np.load(timestamps_npy_path)

# Print the shapes along with the file types.
print("continuous.dat (dtype=float32) shape:", continuous_dat.shape)
print("sample_numbers.npy shape:", sample_numbers_npy.shape)
print("timestamps.npy shape:", timestamps_npy.shape)
